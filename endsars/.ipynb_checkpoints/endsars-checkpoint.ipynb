# %% [markdown]
# ## Scraping tweets

# %%
#!twint -s 'End Sars' --json ./endsars.json -ho

# %% [markdown]
# ## Data Cleaning and EDA

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import wordcloud as wc

# %%
pd.options.display.max_columns=100

# %%
#load scraped tweet from file
tweet1 = pd.read_json('./endsars.json', lines=True)
tweet2 = pd.read_csv('./endsars.csv', sep='\t')
data = pd.concat([tweet1, tweet2], ignore_index=False)

# %%
data.head()
# Out:
#                     id      conversation_id  \
# 0  1374731690187296771  1374711687853531136
# 1  1374731603772063746  1374731603772063744
# 2  1374731390982438918  1374730915537158144
# 3  1374731345918898176  1374731345918898176
# 4  1374731332455137282  1374728771530539008
#
#                                           created_at                 date  \
# 0  2021-03-24 15:35:50 W. Central Africa Standard...  2021-03-24 00:00:00
# 1  2021-03-24 15:35:30 W. Central Africa Standard...  2021-03-24 00:00:00
# 2  2021-03-24 15:34:39 W. Central Africa Standard...  2021-03-24 00:00:00
# 3  2021-03-24 15:34:28 W. Central Africa Standard...  2021-03-24 00:00:00
# 4  2021-03-24 15:34:25 W. Central Africa Standard...  2021-03-24 00:00:00
#
#        time  timezone              user_id         username  \
# 0  15:35:50       100           2527784056      de_paragon1
# 1  15:35:30       100            143812224     edwardessien
# 2  15:34:39       100  1147389496448749568   julietrixhinna
# 3  15:34:28       100  1326270907644583948    olawalenedved
# 4  15:34:25       100  1278267037404594176  underscoretunc1
#
#                                                name place  \
# 0                                    E.M.EKAрџ—ЇпёЏ
# 1                                     Edward Essien
# 2                                    JULIET#Endsars
# 3           Nedved рџ‡ірџ‡¬рџ‡єрџ‡ёрџ¤ґрџЏѕ#EndSARS
# 4  рџ”Ґв™Ёрџ‡±рџ‡ѕ #EndSars D рџ‘Ђ рџ‡±рџ‡ѕ в™Ёрџ”Ґ
#
#                                                tweet language  \
# 0  @SaharaReporters @HQNigerianArmy There is no e...       en
# 1  We are too foolish in this southern part of th...       en
# 2                         @DONJAZZY @crayonthis Nice       en
# 3  @HQNigerianArmy and @PoliceNG  are killing the...       en
# 4  @SaharaReporters @MBuhari @NGRPresident #EndSa...       en
#
#                                             mentions urls photos  \
# 0  [{'screen_name': 'saharareporters', 'name': 's...   []     []
# 1  [{'screen_name': 'jidesanwoolu', 'name': 'baba...   []     []
# 2                                                 []   []     []
# 3  [{'screen_name': 'policeng', 'name': 'nigeria ...   []     []
# 4                                                 []   []     []
#
#    replies_count  retweets_count  likes_count                    hashtags  \
# 0              0               0            0                   [endsars]
# 1              0               0            0    [lekkitollgate, endsars]
# 2              0               0            0                          []
# 3              0               0            0    [revolutionnow, endsars]
# 4              0               0            0  [endsars, mbuhari, change]
#
#   cashtags                                               link  retweet  \
# 0       []  https://twitter.com/De_Paragon1/status/1374731...    False
# 1       []  https://twitter.com/edwardessien/status/137473...    False
# 2       []  https://twitter.com/julietrixhinna/status/1374...    False
# 3       []  https://twitter.com/OlawaleNedved/status/13747...    False
# 4       []  https://twitter.com/UnderscoreTunc1/status/137...    False
#
#                                            quote_url  video thumbnail near  \
# 0                                                         0
# 1  https://twitter.com/channelstv/status/13747216...      0
# 2                                                         0
# 3                                                         0
# 4                                                         0
#
#   geo source user_rt_id user_rt retweet_id  \
# 0
# 1
# 2
# 3
# 4
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'SaharaReporters', 'name': 'S...
# 1                                                 []
# 2  [{'screen_name': 'DONJAZZY', 'name': 'ITвЂ™S D...
# 3                                                 []
# 4  [{'screen_name': 'SaharaReporters', 'name': 'S...
#
#   trans_src trans_dest
# 0
# 1
# 2
# 3
# 4

# %%
data.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
tweets = data[['date', 'tweet', 'language', 'hashtags']]
tweets.head()
# Out:
#                   date                                              tweet  \
# 0  2021-03-24 00:00:00  @SaharaReporters @HQNigerianArmy There is no e...
# 1  2021-03-24 00:00:00  We are too foolish in this southern part of th...
# 2  2021-03-24 00:00:00                         @DONJAZZY @crayonthis Nice
# 3  2021-03-24 00:00:00  @HQNigerianArmy and @PoliceNG  are killing the...
# 4  2021-03-24 00:00:00  @SaharaReporters @MBuhari @NGRPresident #EndSa...
#
#   language                    hashtags
# 0       en                   [endsars]
# 1       en    [lekkitollgate, endsars]
# 2       en                          []
# 3       en    [revolutionnow, endsars]
# 4       en  [endsars, mbuhari, change]

# %%
h = []
for i in tweets['hashtags']:
    h+=i
hashtags_str = ' '.join(h)

# %%
print("HASHTAGS\n")
hashtag_wc = wc.WordCloud(width=720, height=720, min_word_length=3)
display(hashtag_wc.generate(hashtags_str).to_image())
# Out:
# HASHTAGS
# <PIL.Image.Image image mode=RGB size=720x720 at 0x27CA19B6908>

# %%
mentions = tweets['tweet'].str.extractall(r"(@\S+)")

# %%
mentions = mentions[0].value_counts().to_dict()

# %%
print("MENTIONS\n")
mentions_wc = wc.WordCloud(width=520, height=520)
display(mentions_wc.generate_from_frequencies(mentions).to_image())
# Out:
# MENTIONS
# <PIL.Image.Image image mode=RGB size=520x520 at 0x27CA4816688>

# %%
tweets['date'].value_counts()
# Out:
# 2021-03-23 00:00:00    3377
# 2021-03-23             3376
# 2021-03-22 00:00:00    3062
# 2021-03-22             3058
# 2021-03-24             2729
# 2021-03-21 00:00:00    2065
# 2021-03-21             1913
# 2021-03-24 00:00:00    1736
# Name: date, dtype: int64

# %%
language = tweets['language'].value_counts()

# %%
l_index = [
 'English', 'Unknown', 'French', 'Tagalog', 'Indonesian', 'Spanish', 'Haitian Creole', 'Portuguese',
 'Danish', 'German', 'Estonian', 'Polish', 'Italian', 'Turkish', 'Basque', 'Icelandic', 'Dutch ',
 'Catalan', 'Norwegian', 'Welsh', 'Czech', 'Swedish', 'Finnish', 'Vietnamese', 'Latvian', 'Lithuanian',
 'Japanese', 'Romanian', 'Hindi'
]

# %%
language.index=l_index
language
# Out:
# English           17286
# Unknown            2657
# French              326
# Tagalog             233
# Indonesian          165
# Spanish              97
# Haitian Creole       90
# Portuguese           58
# Danish               53
# German               49
# Estonian             40
# Polish               38
# Italian              31
# Turkish              30
# Basque               19
# Icelandic            18
# Dutch                18
# Catalan              16
# Norwegian            16
# Welsh                15
# Czech                13
# Swedish              10
# Finnish               9
# Vietnamese            6
# Latvian               6
# Lithuanian            6
# Japanese              4
# Romanian              4
# Hindi                 3
# Name: language, dtype: int64

# %%
language.plot.barh(figsize=(10,5))
plt.title('Tweets Language')
# Out:
# Text(0.5, 1.0, 'Tweets Language')

# %% [markdown]
# People from various countries tweeted about the #ENDSARS movement

# %%
import re

def clean_tweet(text):
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub('r<.*?>', '', text)
    return text

# %%
# Drop all tweets that were tweeted in other languages aside English.
tweets = tweets[tweets['language']=='en']
tweets.shape
# Out:
# (17286, 4)

# %% [markdown]
# ## Sentiment Analysis with VADER sentiment analyzer
# Developed in 2014, VADER (Valence Aware Dictionary and sEntiment Reasoner) is a pre-trained model that uses rule-based values tuned to sentiments from social media. It evaluates the text of a message and gives you an assessment of not just positive and negative, but the intensity of that emotion as well.
#
# It uses a dictionary of terms that it can evaluate. From the GitHub repository this includes examples like:
#
# Negations - a modifier that reverses the meaning of a phrase ("not great").
# Contractions - negations, but more complex ("wasn’t great").
# Punctuation - increased intensity ("It’s great!!!").
# Slang - variations of slang words such as "kinda", "sux", or "hella".
# It's even able to understand acronyms ("lol") and emoji (❤).

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# gets the likely sentiment of a tweet Using the NLTK VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# %% [markdown]
# #### VADER sentiment analyzer isn't necessarily affected whether the text is cleaned or not as it is built to handle social media data and this is proved below

# %%
sample = ''.join(tweets['tweet'][0].values)
sample
# Out:
# '@SaharaReporters @HQNigerianArmy There is no evidence they are ESN members.. Just gather boys on the street, kill them and tag them IPOB.  @SaharaReporters I\'m quite disappointed in you people to tag extrajudicial killing of youths "ESN".  Nigerian Soldiers killed #EndSARS protesters and lied but u believed thiswhen you’re bisexually in love with your opposite sex partner but also wanna whoop on them for making you look str8  https://t.co/euxEnX1fy5'

# %%
sample_cleaned = clean_tweet(''.join(sample))
sample_cleaned
# Out:
# '  There is no evidence they are ESN members.. Just gather boys on the street, kill them and tag them IPOB.   I\'m quite disappointed in you people to tag extrajudicial killing of youths "ESN".  Nigerian Soldiers killed  protesters and lied but u believed thiswhen you’re bisexually in love with your opposite sex partner but also wanna whoop on them for making you look str  '

# %%
analyzer.polarity_scores(sample)
# Out:
# {'neg': 0.191, 'neu': 0.736, 'pos': 0.072, 'compound': -0.6753}

# %% [markdown]
# #### compound ranges from -1 to 1 and the closer the compund is to 1 the more positive the sentiment will be and the more it is to -1 the more negative the sentiment will be

# %%
analyzer.polarity_scores(sample_cleaned)
# Out:
# {'neg': 0.204, 'neu': 0.719, 'pos': 0.077, 'compound': -0.6753}

# %%
def get_sentiment(data):
    """
    Get sentiment for the comments in the data.
    """
    score = analyzer.polarity_scores(data)
    if score['compound'] > 0.05: print('Positive')
    elif score['compound'] < -0.05: print('Negative')
    else: print('Neutral')

# %%
get_sentiment(sample)
# Out:
# Negative

# %%
get_sentiment(sample_cleaned)
# Out:
# Negative

# %%
def get_sentiment(data):
    """
    Get sentiment for the tweets in the data.
    """
    sentiments = []
    sentiment_probab = []
    for comment in data['tweet']:
        #comment = ''.join(comment.values)
        score = analyzer.polarity_scores(comment)
        sentiment_probab.append(score['compound'])
        if score['compound'] > 0:
            sentiments.append('Positive')
        else:
            sentiments.append('Negative')
    data['sentiments'] = sentiments
    data['compound'] = sentiment_probab
    return data

# %%
# assigne sentiment to tweets
tweet_sent = get_sentiment(tweets)

# %%
tweet_sent.head()
# Out:
#                   date                                              tweet  \
# 0  2021-03-24 00:00:00  @SaharaReporters @HQNigerianArmy There is no e...
# 1  2021-03-24 00:00:00  We are too foolish in this southern part of th...
# 2  2021-03-24 00:00:00                         @DONJAZZY @crayonthis Nice
# 3  2021-03-24 00:00:00  @HQNigerianArmy and @PoliceNG  are killing the...
# 4  2021-03-24 00:00:00  @SaharaReporters @MBuhari @NGRPresident #EndSa...
#
#   language                    hashtags sentiments  compound
# 0       en                   [endsars]   Negative   -0.9071
# 1       en    [lekkitollgate, endsars]   Negative   -0.8934
# 2       en                          []   Positive    0.4215
# 3       en    [revolutionnow, endsars]   Negative   -0.8689
# 4       en  [endsars, mbuhari, change]   Negative   -0.8020

# %%
sentiment = tweet_sent['sentiments'].value_counts()

# %%
sentiment.plot.bar()
plt.ylabel('Number of tweets')
plt.xlabel('Sentiments')
# Out:
# Text(0.5, 0, 'Sentiments')

# %%
# Sample of tweets with positive sentiment
for tweet in tweet_sent[tweet_sent['sentiments']=='Positive']['tweet'][:10]:
    print(clean_tweet(tweet), end='\n\n')
# Out:
#   Nice
#
#  Cute рџҐ°
#
# The Nigerian police force clearly learnt nothing from the October end SARS protests.... How do u beat up a guy just cos he doesn't have the receipt to his phone? Like how?
#
#   I don join the queue. LetвЂ™s go
#
# So proud of you auntyвќ¤пёЏвќ¤пёЏ
#
#   kindly look at this and commence your investigation!
#
# Love you baby рџ�—.  Happy birthday рџҐірџҐірџЋ‚
#
#   Thank youрџ¤—
#
# I know damn well this dude isn't out here vaping on this carrer informational session on zoom. Like sit that's a prospective employer talking lol
#
#  Sis is suffering from internalised misogyny we need to give prayer. Because this isnвЂ™t the prize

# %%
date_plot = tweets['date'].apply(lambda x: pd.to_datetime(x))
date_plot = date_plot.apply(lambda x:x.strftime("%B %d"))
date_plot.value_counts()
# Out:
# March 23    5481
# March 22    4910
# March 24    3677
# March 21    3218
# Name: date, dtype: int64

# %%
date_df = tweets[['date', 'sentiments']]
date_df['date'] = date_plot
date_df.head()
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        date sentiments
# 0  March 24   Negative
# 1  March 24   Negative
# 2  March 24   Positive
# 3  March 24   Negative
# 4  March 24   Negative

# %%
date_values = sorted(set(date_plot.values))
date_values
# Out:
# ['March 21', 'March 22', 'March 23', 'March 24']

# %%
fig = plt.figure(figsize=(15,8))
# Create DataFrame containing categories and count of each
frame = pd.DataFrame(index = np.arange(len(date_values)), columns=('date','Positive','Negative'))
for i, value in enumerate(date_values):
    #print(value)
    frame.loc[i] = [value, \
        len(date_df[(date_df['sentiments'] == "Positive") & (date_df["date"] == value)]), \
        len(date_df[(date_df['sentiments'] == "Negative") & (date_df["date"] == value)])]

    # Set the width of each bar
    bar_width = 0.4

    # Display each category's survival rates
    for i in np.arange(len(frame)):
        neg_bar = plt.bar(i-bar_width, frame.loc[i]['Negative'], width = bar_width, color = 'r')
        pos_bar = plt.bar(i, frame.loc[i]['Positive'], width = bar_width, color = 'g')

        plt.xticks(np.arange(len(frame)), date_values)
        plt.legend((neg_bar[0], pos_bar[0]),('Negative', 'Positive'), framealpha = 0.8, loc=1)

# %%
for i in sorted(date_values):
    print(f"{i}, Positive: {frame.loc[frame['date']==i, 'Positive'].sum()} Negative: {frame.loc[frame['date']==i, 'Negative'].sum()}")
# Out:
# March 21, Positive: 1189 Negative: 2029
# March 22, Positive: 1711 Negative: 3199
# March 23, Positive: 2183 Negative: 3298
# March 24, Positive: 1426 Negative: 2251
